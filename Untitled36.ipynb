# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Snehja Srivastava\Downloads\Sorted by Subject Code.csv')

# %%
df
# Out:
#      Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# 0                                                 S.No.
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 1099                                               1099
# 1100                                               1100
# 1101                                               1101
# 1102                                               1102
# 1103                                               1103
#
#         Unnamed: 1                                         Unnamed: 2  \
# 0     Subject Code                                      Subject Title
# 1         BTPC-201                                       Microbiology
# ...

# %%
df.describe()
# Out:
#        Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# count                                                1104
# unique                                               1104
# top                                                 S.No.
# freq                                                    1
#
#        Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# count        1104          1104       1078       1104              1104
# unique        234           219          5        613               599
# top      MEPC-309  Mechatronics          3   21110059  VISHWAJEET SINGH
# freq           46            47        610          3                 5
#
#        Unnamed: 6              Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# count        1104                    1104       1104       1104        1104
# unique          5                      19          6          9           4
# ...

# %%
df.dtypes
# Out:
# Summer Course Registration (June 2023) - Sorted by Subject Code\n\n    object
# Unnamed: 1                                                             object
# Unnamed: 2                                                             object
# Unnamed: 3                                                             object
# Unnamed: 4                                                             object
# Unnamed: 5                                                             object
# Unnamed: 6                                                             object
# Unnamed: 7                                                             object
# Unnamed: 8                                                             object
# Unnamed: 9                                                             object
# Unnamed: 10                                                            object
# Unnamed: 11                                                            object
# ...
