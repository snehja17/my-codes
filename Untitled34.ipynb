# %%
import pandas as pd

# %%
pd=pd.read_csv(r'C:\Users\Snehja Srivastava\Downloads\Sorted by Subject Code.csv')

# %%
pd
# Out:
#      Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# 0                                                 S.No.
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 1099                                               1099
# 1100                                               1100
# 1101                                               1101
# 1102                                               1102
# 1103                                               1103
#
#         Unnamed: 1                                         Unnamed: 2  \
# 0     Subject Code                                      Subject Title
# 1         BTPC-201                                       Microbiology
# ...

# %%
pd.head()
# Out:
#   Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# 0                                              S.No.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#      Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# 0  Subject Code  Subject Title    Credits   Roll No.              Name
# 1      BTPC-201   Microbiology          3   21111011     ARUSH PANCHAL
# 2      BTPC-201   Microbiology          3   21111025                 n
# 3      BTPC-201   Microbiology          3   21111033    PREETPAL SINGH
# 4      BTPC-201   Microbiology          3   21111035  PUSHPINDER SINGH
#
#   Unnamed: 6      Unnamed: 7 Unnamed: 8           Unnamed: 9    Unnamed: 10  \
# 0     Course          Branch      Batch  Semester (Reappear)  Current Grade
# ...

# %%
pd.tail()
# Out:
#      Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# 1099                                               1099
# 1100                                               1100
# 1101                                               1101
# 1102                                               1102
# 1103                                               1103
#
#      Unnamed: 1                                         Unnamed: 2 Unnamed: 3  \
# 1099     HM-517                                 Consumer Behaviour        NaN
# 1100     HM-519                              Marketing of Services        NaN
# 1101     HM-519                              Marketing of Services        NaN
# 1102     HM-519                              Marketing of Services        NaN
# 1103     MB-552  Management of Financial Services and Institutions          3
#
#      Unnamed: 4              Unnamed: 5 Unnamed: 6                 Unnamed: 7  \
# ...

# %%
df=pd

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Summer Course Registration (June 2023) - Sorted by Subject Code\n\n  \
# 0                                              S.No.
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#      Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4        Unnamed: 5  \
# 0  Subject Code  Subject Title    Credits   Roll No.              Name
# 1      BTPC-201   Microbiology          3   21111011     ARUSH PANCHAL
# 2      BTPC-201   Microbiology          3   21111025                 n
# 3      BTPC-201   Microbiology          3   21111033    PREETPAL SINGH
# 4      BTPC-201   Microbiology          3   21111035  PUSHPINDER SINGH
#
#   Unnamed: 6      Unnamed: 7 Unnamed: 8           Unnamed: 9    Unnamed: 10  \
# 0     Course          Branch      Batch  Semester (Reappear)  Current Grade
# ...

# %%
df1=df.head()
df1.to_csv("test.csv")

# %%
pwd()
# Out:
# 'C:\\Users\\Snehja Srivastava'
