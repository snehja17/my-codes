# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# FIND ME NAME CORRESPONDING TO HIGHEST FARE

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'][df['Fare']==max(df['Fare'])]
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: Fare, dtype: float64

# %%
np.where(df['Fare']==max(df['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))] ['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# find name of persons whose age is 24

# %%
np.where(df['Age']== 24)
# Out:
# (array([ 89, 118, 127, 139, 142, 199, 210, 234, 247, 293, 294, 310, 316,
#         341, 345, 369, 394, 437, 499, 514, 565, 600, 615, 641, 655, 710,
#         743, 770, 858, 864], dtype=int64),)

# %%
df.iloc[np.where(df['Age']== 24)]
# Out:
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
# 199          200         0       2
# 210          211         0       3
# 234          235         0       2
# 247          248         1       2
# 293          294         0       3
# 294          295         0       3
# 310          311         1       1
# 316          317         1       2
# 341          342         1       1
# 345          346         1       2
# 369          370         1       1
# 394          395         1       3
# 437          438         1       2
# 499          500         0       3
# 514          515         0       3
# 565          566         0       3
# 600          601         1       2
# 615          616         1       2
# 641          642         1       1
# 655          656         0       2
# ...

# %%
df.iloc[np.where(df['Age']== 24)] [ ['Name' , 'Cabin']]      # note double brackets in name and cabin else single brac mei it wont work
# Out:
#                                                   Name        Cabin
# 89                              Celotti, Mr. Francesco          NaN
# 118                           Baxter, Mr. Quigg Edmond      B58 B60
# 127                          Madsen, Mr. Fridtjof Arne          NaN
# 139                                 Giglio, Mr. Victor          B86
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...          NaN
# 199             Yrois, Miss. Henriette ("Mrs Harbeck")          NaN
# 210                                     Ali, Mr. Ahmed          NaN
# 234                  Leyson, Mr. Robert William Norman          NaN
# 247                    Hamalainen, Mrs. William (Anna)          NaN
# 293                                Haas, Miss. Aloisia          NaN
# 294                                   Mineff, Mr. Ivan          NaN
# 310                     Hays, Miss. Margaret Bechstein          C54
# 316                Kantor, Mrs. Sinai (Miriam Sternin)          NaN
# ...

# %%
df['Age'] [df['Age']== 24]

# %%
# HOW MANY MALE PASSENGERS SURVIVED

# %%
np.where(df['Survived']==1) and (df['Sex']=='male')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool
