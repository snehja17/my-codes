# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'][0:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
df['Age'].isnull()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'][df['Age'].isnull()==True]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64

# %%
df1=df['Age'][df['Age'].isnull()==True].index            #  we get index numbers

# %%
df2=np.where(df['Age'].isnull()==True)

# %%
df1
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
df2
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %% [markdown]
# df.iloc[df2] is valid code

# %%
df.iloc[df1,:2]                 #ERROR ALERT: df2 mat laga dena in place of df1
# Out:
#      PassengerId  Survived
# 5              6         0
# 17            18         1
# 19            20         1
# 26            27         0
# 28            29         1
# ..           ...       ...
# 859          860         0
# 863          864         0
# 868          869         0
# 878          879         0
# 888          889         0
#
# [177 rows x 2 columns]

# %%
list(df1)
# Out:
# [5,
#  17,
#  19,
#  26,
#  28,
#  29,
#  31,
#  32,
#  36,
#  42,
#  45,
#  46,
#  47,
#  48,
#  55,
#  64,
#  65,
#  76,
#  77,
#  82,
#  87,
#  95,
#  101,
#  107,
#  109,
#  121,
#  126,
#  128,
#  140,
#  154,
#  158,
#  159,
#  166,
#  168,
#  176,
#  180,
#  181,
#  185,
#  186,
#  196,
#  198,
#  201,
#  214,
#  223,
#  229,
#  235,
#  240,
#  241,
#  250,
#  256,
#  260,
#  264,
#  270,
#  274,
#  277,
#  284,
#  295,
#  298,
#  300,
#  301,
#  303,
#  304,
#  306,
#  324,
#  330,
#  334,
#  335,
#  347,
#  351,
#  354,
#  358,
#  359,
#  364,
#  367,
#  368,
#  375,
#  384,
#  388,
#  409,
#  410,
#  411,
#  413,
#  415,
#  420,
#  425,
#  428,
#  431,
#  444,
#  451,
#  454,
#  457,
#  459,
#  464,
#  466,
#  468,
#  470,
#  475,
#  481,
#  485,
#  490,
#  495,
#  497,
#  502,
#  507,
#  511,
#  517,
#  522,
#  524,
#  527,
#  531,
#  533,
#  538,
#  547,
#  552,
#  557,
#  560,
#  563,
#  564,
#  568,
#  573,
#  578,
#  584,
#  589,
#  593,
#  596,
#  598,
#  601,
# ...

# %%
  df3=  np.where (    df['Fare']==max(df['Fare'])    )

# %%
df3
# Out:
# (array([258, 679, 737], dtype=int64),)

# %% [markdown]
# df3

# %%
df["Fare"] [(df['Fare']==max(df['Fare']))]
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: Fare, dtype: float64

# %%
df.iloc[df3]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
